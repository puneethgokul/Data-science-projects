# %% [markdown]
# # Ensemble Techniques Project

# %%
#Importing libraries and dataset
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt       # matplotlib.pyplot plots data
# %matplotlib inline 
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv('Data - Parkinsons')

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer    ...     \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374    ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134    ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233    ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492    ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425    ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# Overview of the dataset - 24 COlumns, 194 Rows, No Missing values,  all the columns are float values except the status column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
# name                195 non-null object
# MDVP:Fo(Hz)         195 non-null float64
# MDVP:Fhi(Hz)        195 non-null float64
# MDVP:Flo(Hz)        195 non-null float64
# MDVP:Jitter(%)      195 non-null float64
# MDVP:Jitter(Abs)    195 non-null float64
# MDVP:RAP            195 non-null float64
# MDVP:PPQ            195 non-null float64
# Jitter:DDP          195 non-null float64
# MDVP:Shimmer        195 non-null float64
# MDVP:Shimmer(dB)    195 non-null float64
# Shimmer:APQ3        195 non-null float64
# Shimmer:APQ5        195 non-null float64
# MDVP:APQ            195 non-null float64
# Shimmer:DDA         195 non-null float64
# NHR                 195 non-null float64
# HNR                 195 non-null float64
# status              195 non-null int64
# RPDE                195 non-null float64
# DFA                 195 non-null float64
# ...

# %% [markdown]
# No missing values

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# MDVP:Fo(Hz) column- slightly right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Fo(Hz)']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Fo(Hz)'],orient = "v")

# %% [markdown]
# MDVP:Fhi(Hz) column-  right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Fhi(Hz)']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Fhi(Hz)'],orient = "v")

# %% [markdown]
# MDVP:Flo(Hz) column - slightly right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Flo(Hz)']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Flo(Hz)'],orient = "v")

# %% [markdown]
# MDVP:Jitter(%) column -  right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Jitter(%)']*100) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Jitter(%)']*100,orient = "v")

# %% [markdown]
# MDVP:Jitter(Abs) column -  right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Jitter(Abs)']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Jitter(Abs)'],orient = "v")

# %% [markdown]
# MDVP:RAP column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:RAP']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:RAP'],orient = "v")

# %% [markdown]
# MDVP:PPQ column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:PPQ']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:PPQ'],orient = "v")

# %% [markdown]
# Jitter:DDP column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['Jitter:DDP']) 

plt.subplot(1,2,2)
sns.boxplot(df['Jitter:DDP'],orient = "v")

# %% [markdown]
# MDVP:Shimmer column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Shimmer']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Shimmer'],orient = "v")

# %% [markdown]
# MDVP:Shimmer(dB) column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:Shimmer(dB)']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:Shimmer(dB)'],orient = "v")

# %% [markdown]
# Shimmer:APQ3 column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['Shimmer:APQ3']) 

plt.subplot(1,2,2)
sns.boxplot(df['Shimmer:APQ3'],orient = "v")

# %% [markdown]
# Shimmer:APQ5 column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['Shimmer:APQ5']) 

plt.subplot(1,2,2)
sns.boxplot(df['Shimmer:APQ5'],orient = "v")

# %% [markdown]
# MDVP:APQ column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['MDVP:APQ']) 

plt.subplot(1,2,2)
sns.boxplot(df['MDVP:APQ'],orient = "v")

# %% [markdown]
# Shimmer:DDA column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['Shimmer:DDA']) 

plt.subplot(1,2,2)
sns.boxplot(df['Shimmer:DDA'],orient = "v")

# %% [markdown]
# NHR column - right skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['NHR']) 

plt.subplot(1,2,2)
sns.boxplot(df['NHR'],orient = "v")

# %% [markdown]
# HNR column - close to normal distribution

# %%
plt.subplot(1,2,1)
sns.distplot(df['HNR']) 

plt.subplot(1,2,2)
sns.boxplot(df['HNR'],orient = "v")

# %% [markdown]
# RPDE column - close to normal distribution

# %%
plt.subplot(1,2,1)
sns.distplot(df['RPDE']) 

plt.subplot(1,2,2)
sns.boxplot(df['RPDE'],orient = "v")

# %% [markdown]
# DFA column - close to normal distribution

# %%
plt.subplot(1,2,1)
sns.distplot(df['DFA']) 

plt.subplot(1,2,2)
sns.boxplot(df['DFA'],orient = "v")

# %% [markdown]
# spread1 column - close to normal distribution

# %%
plt.subplot(1,2,1)
sns.distplot(df['spread1']) 

plt.subplot(1,2,2)
sns.boxplot(df['spread1'],orient = "v")

# %% [markdown]
# spread2 column - close to normal distribution

# %%
plt.subplot(1,2,1)
sns.distplot(df['spread2']) 

plt.subplot(1,2,2)
sns.boxplot(df['spread2'],orient = "v")

# %% [markdown]
# D2 column - close to normal distribution

# %%
plt.subplot(1,2,1)
sns.distplot(df['D2']) 

plt.subplot(1,2,2)
sns.boxplot(df['D2'],orient = "v")

# %% [markdown]
# PPE column - left skewed

# %%
plt.subplot(1,2,1)
sns.distplot(df['PPE']) 

plt.subplot(1,2,2)
sns.boxplot(df['PPE'],orient = "v")

# %% [markdown]
# Status column - More number of parkinsons detected

# %%
sns.countplot(df['status'])

# %% [markdown]
# #Preparing the Data

# %%
X = df.drop(['name', 'status'],axis=1)     
Y = df['status']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1,stratify = Y)

# %%
plt.subplot(1,2,1)
y_train.value_counts().plot(kind = 'bar')

plt.subplot(1,2,2)
y_test.value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(max_iter = 1000)

model_lr.fit(x_train, y_train)

y_predict_lr= model_lr.predict(x_test)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

cm_lr = metrics.confusion_matrix(y_test, y_predict_lr,labels=[1,0])
sns.heatmap(cm_lr, annot= True, yticklabels = [1,0], xticklabels = [1,0], cmap = 'viridis',annot_kws={"size": 16},linewidths= 3,fmt='g')

print("")

print("Accuracy of Logistic regression model is {}%".format(accuracy_score(y_test, y_predict_lr)*100))
# Out:
# Accuracy of Logistic regression model is 89.83050847457628%

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

model_NB = GaussianNB()

model_NB.fit(x_train, y_train)

y_predict_NB= model_NB.predict(x_test)

# %%
cm_NB = metrics.confusion_matrix(y_test, y_predict_NB,labels=[1,0])
sns.heatmap(cm_NB, annot= True, yticklabels = [1,0], xticklabels = [1,0], cmap = 'viridis',annot_kws={"size": 16},linewidths= 3,fmt='g')

print("")

print("Accuracy of Naive Bayes model is {}%".format(accuracy_score(y_test, y_predict_NB)*100))
# Out:
# Accuracy of Naive Bayes model is 69.49152542372882%

# %% [markdown]
# K-Nearest Neighbours

# %%
#checking what value of 'K' gives the highest accuracy on the testing dataset
from sklearn.neighbors import KNeighborsClassifier
scores =[]
for k in range(1,75):
    NNH = KNeighborsClassifier(n_neighbors = k, weights = 'distance' )
    NNH.fit(x_train, y_train)
    scores.append(NNH.score(x_test, y_test))

plt.plot(range(1,75),scores)

# %%
model_KNN = KNeighborsClassifier(n_neighbors = 3)

model_KNN.fit(x_train, y_train)

y_predict_KNN= model_KNN.predict(x_test)

# %%
cm_knn = metrics.confusion_matrix(y_test, y_predict_KNN,labels=[1,0])
sns.heatmap(cm_knn, annot= True, yticklabels = [1,0], xticklabels = [1,0], cmap = 'viridis',annot_kws={"size": 16},linewidths= 3,fmt='g')



print("Accuracy of K-Nearest Neighbours model is {}%".format(accuracy_score(y_test, y_predict_KNN)*100))
# Out:
# Accuracy of K-Nearest Neighbours model is 88.13559322033898%

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfcl = RandomForestClassifier(n_estimators = 100,  max_depth = 6,  max_features=5)

model_rfcl = rfcl.fit(x_train, y_train)

y_predict_rfcl= model_rfcl.predict(x_test)

# %%
cm_rfcl = metrics.confusion_matrix(y_test, y_predict_rfcl,labels=[1,0])
sns.heatmap(cm_rfcl, annot= True, yticklabels = [1,0], xticklabels = [1,0], cmap = 'viridis',annot_kws={"size": 16},linewidths= 3,fmt='g')

print("")

print("Accuracy of Random forest model is {}%".format(accuracy_score(y_test, y_predict_rfcl)*100))
# Out:
# Accuracy of Random forest model is 94.91525423728814%

# %% [markdown]
# Stacked classifier

# %%
from sklearn.ensemble import StackingClassifier
stcl = StackingClassifier(estimators =[('rfcl',RandomForestClassifier()),
                                     ('model_knn',KNeighborsClassifier()),
                                     ('model_lr',LogisticRegression()),
                                    ('model_NB', GaussianNB())])

stcl.fit(x_train, y_train)

y_predict_stcl = stcl.predict(x_test)

import warnings
warnings.filterwarnings("ignore")

# %%
cm_stcl = metrics.confusion_matrix(y_test, y_predict_stcl,labels=[1,0])
sns.heatmap(cm_stcl, annot= True, yticklabels = [1,0], xticklabels = [1,0], cmap = 'viridis',annot_kws={"size": 16},linewidths= 3,fmt='g')

print("")

print("Accuracy of stacked classifier model is {}%".format(accuracy_score(y_test, y_predict_stcl)*100))
# Out:
# Accuracy of stacked classifier model is 89.83050847457628%

# %% [markdown]
# Best model

# %%
print("Accuracy of Logistic regression model is {:.2f}%".format(accuracy_score(y_test, y_predict_lr)*100))
print(" ")
print("Accuracy of Naive Bayes model is {:.2f}%".format(accuracy_score(y_test, y_predict_NB)*100))
print(" ")
print("Accuracy of K-Nearest Neighbours model is {:.2f}%".format(accuracy_score(y_test, y_predict_KNN)*100))
print(" ")
print("Accuracy of Random forest model is {:.2f}%".format(accuracy_score(y_test, y_predict_rfcl)*100))
print(" ")
print("Accuracy of stacked classifier model is {:.2f}%".format(accuracy_score(y_test, y_predict_stcl)*100))
# Out:
# Accuracy of Logistic regression model is 89.83%
#
# Accuracy of Naive Bayes model is 69.49%
#
# Accuracy of K-Nearest Neighbours model is 88.14%
#
# Accuracy of Random forest model is 94.92%
#
# Accuracy of stacked classifier model is 89.83%

# %% [markdown]
# Hence, we can conclude that random forest is the best model in this case with 95% accuracy
